# %% [markdown]
# <a href="https://colab.research.google.com/github/Jatansahu/GOLDDIGGER_GROUP12_PROJECT_01/blob/main/Data_prepration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1) Importing Libraries

# %%
import pandas as pd
# import polars as p
import numpy as np
import warnings
warnings.filterwarnings(action = "ignore")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %% [markdown]
# #2) Loading Dataset

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Jatansahu/GOLDDIGGER_GROUP12_PROJECT_01/main/dataset.csv")

# %%
# Previewing data
data.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2011     2011           AL      Alabama
# 1       2011     2011           AL      Alabama
# 2       2011     2011           AL      Alabama
# 3       2011     2011           AL      Alabama
# 4       2011     2011           AL      Alabama
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
#
#                      Topic                                           Question  \
# 0  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# 1  Obesity / Weight Status  Percent of adults aged 18 years and older who ...
# ...

# %% [markdown]
# **Looking at the above dataset our target variable is the column "data_value".**

# %% [markdown]
# #3) Data Description

# %%
data.describe()
# Out:
#           YearStart       YearEnd  Data_Value_Unit    Data_Value  \
# count  53392.000000  53392.000000              0.0  48346.000000
# mean    2013.281465   2013.281465              NaN     31.156681
# std        1.693300      1.693300              NaN     10.247033
# min     2011.000000   2011.000000              NaN      0.900000
# 25%     2012.000000   2012.000000              NaN     24.100000
# 50%     2013.000000   2013.000000              NaN     30.700000
# 75%     2015.000000   2015.000000              NaN     37.000000
# max     2016.000000   2016.000000              NaN     77.600000
#
#        Data_Value_Alt  Low_Confidence_Limit  High_Confidence_Limit   \
# count    48346.000000          48346.000000            48346.000000
# mean        31.156681             26.892227               35.989997
# std         10.247033             10.038584               11.205813
# min          0.900000              0.300000                3.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53392 entries, 0 to 53391
# Data columns (total 33 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   YearStart                   53392 non-null  int64
#  1   YearEnd                     53392 non-null  int64
#  2   LocationAbbr                53392 non-null  object
#  3   LocationDesc                53392 non-null  object
#  4   Datasource                  53392 non-null  object
#  5   Class                       53392 non-null  object
#  6   Topic                       53392 non-null  object
#  7   Question                    53392 non-null  object
#  8   Data_Value_Unit             0 non-null      float64
#  9   Data_Value_Type             53392 non-null  object
#  10  Data_Value                  48346 non-null  float64
#  11  Data_Value_Alt              48346 non-null  float64
#  12  Data_Value_Footnote_Symbol  5046 non-null   object
# ...

# %%
data.shape
# Out:
# (53392, 33)

# %%
col = data.columns
col
# Out:
# Index(['YearStart', 'YearEnd', 'LocationAbbr', 'LocationDesc', 'Datasource',
#        'Class', 'Topic', 'Question', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit ',
#        'Sample_Size', 'Total', 'Age(years)', 'Education', 'Gender', 'Income',
#        'Race/Ethnicity', 'GeoLocation', 'ClassID', 'TopicID', 'QuestionID',
#        'DataValueTypeID', 'LocationID', 'StratificationCategory1',
#        'Stratification1', 'StratificationCategoryId1', 'StratificationID1'],
#       dtype='object')

# %% [markdown]
# #4) Selecting necessary columns

# %% [markdown]
# ## 4.1) Selection of columns

# %% [markdown]
# **Selecting features which will help us to classify different stratification categories.**
#
# Most of the predictive values are correlated to each other so we dropped those columns which have less important(Refer EDA file).

# %%
df = data[['YearEnd','LocationAbbr','Sample_Size','Age(years)','Education','Gender','Income','Race/Ethnicity','ClassID','QuestionID','StratificationCategory1','Stratification1','StratificationCategoryId1','StratificationID1','Total','Data_Value']]

# %%
#dropping columns
for i in df.columns:
  data = data.drop([i],1)

# %%
df
# Out:
#        YearEnd LocationAbbr  Sample_Size Age(years)              Education  \
# 0         2011           AL       7304.0        NaN                    NaN
# 1         2011           AL       2581.0        NaN                    NaN
# 2         2011           AL       4723.0        NaN                    NaN
# 3         2011           AL       1153.0        NaN  Less than high school
# 4         2011           AL       2402.0        NaN   High school graduate
# ...        ...          ...          ...        ...                    ...
# 53387     2016           VI          NaN        NaN                    NaN
# 53388     2016           VI          NaN        NaN                    NaN
# 53389     2016           VI          NaN        NaN                    NaN
# 53390     2016           VI          NaN        NaN                    NaN
# 53391     2016           VI          NaN        NaN                    NaN
#
# ...

# %% [markdown]
# ## 4.2) Reason for removing columns

# %% [markdown]
# *   'Low_Confidence_Limit' => It is the lower limit of our target variable. Closer to Data_value.
# *   'High_Confidence_Limit' => It is the higher limit of our target variable. Closer to Data_value.
#
# *   'Data_Value_Alt' => Closer to Data_value.
# *   'YearEnd' => We have taken starting year. We will take either 'Yearstart' or 'Yearend. Otherwise predator will correlated.
#
# Most of the variables are not relevant to the target variables.

# %% [markdown]
# #5) Data Standardization

# %% [markdown]
# ##5.1) Standardizing column names

# %%
df.columns = df.columns.str.lower()
df.head()
# Out:
#    yearend locationabbr  sample_size age(years)              education  \
# 0     2011           AL       7304.0        NaN                    NaN
# 1     2011           AL       2581.0        NaN                    NaN
# 2     2011           AL       4723.0        NaN                    NaN
# 3     2011           AL       1153.0        NaN  Less than high school
# 4     2011           AL       2402.0        NaN   High school graduate
#
#    gender income race/ethnicity classid questionid stratificationcategory1  \
# 0     NaN    NaN            NaN     OWS       Q036                   Total
# 1    Male    NaN            NaN     OWS       Q036                  Gender
# 2  Female    NaN            NaN     OWS       Q036                  Gender
# 3     NaN    NaN            NaN     OWS       Q036               Education
# 4     NaN    NaN            NaN     OWS       Q036               Education
#
#          stratification1 stratificationcategoryid1 stratificationid1  total  \
# ...

# %% [markdown]
# ##5.2) Optimizing data (Data partitioning)

# %%
distinct_values = df['stratificationcategoryid1'].unique()
distinct_values
# Out:
# array(['OVR', 'GEN', 'EDU', 'AGEYR', 'INC', 'RACE'], dtype=object)

# %% [markdown]
# **Made 6 different dataframes for each category.**

# %%
total = df[df['stratificationcategoryid1'] == 'OVR'] # total
gen = df[df['stratificationcategoryid1'] == 'GEN'] #gender
edu  = df[df['stratificationcategoryid1'] == 'EDU'] #Education
age = df[df['stratificationcategoryid1'] == 'AGEYR'] #Age Range of sample
inc  = df[df['stratificationcategoryid1'] == 'INC'] #income range
race = df[df['stratificationcategoryid1'] == 'RACE'] # race

# %% [markdown]
# ##5.3) Size of each category dataframe

# %%
print(f'Shape of category Race/ethinicity is {race.shape}')
print(f'Shape of category Income range is {inc.shape}')
print(f'Shape of category Age range of sample is {age.shape}')
print(f'Shape of category Education is {edu.shape}')
print(f'Shape of category Gender is {gen.shape}')
print(f'Shape of category total is {total.shape}')
# Out:
# Shape of category Race/ethinicity is (15256, 16)
# Shape of category Income range is (13349, 16)
# Shape of category Age range of sample is (11438, 16)
# Shape of category Education is (7628, 16)
# Shape of category Gender is (3814, 16)
# Shape of category total is (1907, 16)

# %% [markdown]
# #6) Looking for Null values

# %% [markdown]
# ##6.1) For total dataframe

# %%
print(data.isnull().sum())
# Out:
# YearStart                         0
# LocationDesc                      0
# Datasource                        0
# Class                             0
# Topic                             0
# Question                          0
# Data_Value_Unit               53392
# Data_Value_Type                   0
# Data_Value_Alt                 5046
# Data_Value_Footnote_Symbol    48346
# Data_Value_Footnote           48346
# Low_Confidence_Limit           5046
# High_Confidence_Limit          5046
# GeoLocation                    1008
# TopicID                           0
# DataValueTypeID                   0
# LocationID                        0
# dtype: int64

# %% [markdown]
# ##6.2) Missing values (Category wise)

# %% [markdown]
# ###6.2.1) Race

# %%
race.isnull().sum()
# Out:
# yearend                          0
# locationabbr                     0
# sample_size                   5046
# age(years)                   15256
# education                    15256
# gender                       15256
# income                       15256
# race/ethnicity                   0
# classid                          0
# questionid                       0
# stratificationcategory1          0
# stratification1                  0
# stratificationcategoryid1        0
# stratificationid1                0
# total                        15256
# data_value                    5046
# dtype: int64

# %% [markdown]
#   **For race, sample_size and data_value is also null so we will remove these.**

# %%
race= race.dropna(subset=['data_value'])

# %%
race.isnull().sum()
# Out:
# yearend                          0
# locationabbr                     0
# sample_size                      0
# age(years)                   10210
# education                    10210
# gender                       10210
# income                       10210
# race/ethnicity                   0
# classid                          0
# questionid                       0
# stratificationcategory1          0
# stratification1                  0
# stratificationcategoryid1        0
# stratificationid1                0
# total                        10210
# data_value                       0
# dtype: int64

# %% [markdown]
# ###6.2.2) Income

# %%
inc.isnull().sum()
# Out:
# yearend                          0
# locationabbr                     0
# sample_size                      0
# age(years)                   13349
# education                    13349
# gender                       13349
# income                           0
# race/ethnicity               13349
# classid                          0
# questionid                       0
# stratificationcategory1          0
# stratification1                  0
# stratificationcategoryid1        0
# stratificationid1                0
# total                        13349
# data_value                       0
# dtype: int64

# %% [markdown]
# ###6.2.3) Age

# %%
age.isnull().sum()
# Out:
# yearend                          0
# locationabbr                     0
# sample_size                      0
# age(years)                       0
# education                    11438
# gender                       11438
# income                       11438
# race/ethnicity               11438
# classid                          0
# questionid                       0
# stratificationcategory1          0
# stratification1                  0
# stratificationcategoryid1        0
# stratificationid1                0
# total                        11438
# data_value                       0
# dtype: int64

# %% [markdown]
# ###6.2.4) Education

# %%
edu.isnull().sum()
# Out:
# yearend                         0
# locationabbr                    0
# sample_size                     0
# age(years)                   7628
# education                       0
# gender                       7628
# income                       7628
# race/ethnicity               7628
# classid                         0
# questionid                      0
# stratificationcategory1         0
# stratification1                 0
# stratificationcategoryid1       0
# stratificationid1               0
# total                        7628
# data_value                      0
# dtype: int64

# %% [markdown]
# ### 6.2.5) Gender

# %%
gen.isnull().sum()
# Out:
# yearend                         0
# locationabbr                    0
# sample_size                     0
# age(years)                   3814
# education                    3814
# gender                          0
# income                       3814
# race/ethnicity               3814
# classid                         0
# questionid                      0
# stratificationcategory1         0
# stratification1                 0
# stratificationcategoryid1       0
# stratificationid1               0
# total                        3814
# data_value                      0
# dtype: int64

# %% [markdown]
# ###6.2.6) Total

# %%
total.isnull().sum()
# Out:
# yearend                         0
# locationabbr                    0
# sample_size                     0
# age(years)                   1907
# education                    1907
# gender                       1907
# income                       1907
# race/ethnicity               1907
# classid                         0
# questionid                      0
# stratificationcategory1         0
# stratification1                 0
# stratificationcategoryid1       0
# stratificationid1               0
# total                           0
# data_value                      0
# dtype: int64

# %% [markdown]
# ##6.3) Observation
#
# 1.From the above null values we know that for each category other cateregeries values(column) are null so we will remove those feature for particular dataframe
#
# Eg. for race total category other categories(age, education, gender, income, race) are null.
#
# 2 . All the category values are also given in stratification column so we can also drop this column.

# %%
race.head()
# Out:
#     yearend locationabbr  sample_size age(years) education gender income  \
# 20     2011           AL       5042.0        NaN       NaN    NaN    NaN
# 21     2011           AL       1878.0        NaN       NaN    NaN    NaN
# 22     2011           AL        115.0        NaN       NaN    NaN    NaN
# 25     2011           AL         61.0        NaN       NaN    NaN    NaN
# 26     2011           AL         58.0        NaN       NaN    NaN    NaN
#
#                    race/ethnicity classid questionid stratificationcategory1  \
# 20             Non-Hispanic White     OWS       Q036          Race/Ethnicity
# 21             Non-Hispanic Black     OWS       Q036          Race/Ethnicity
# 22                       Hispanic     OWS       Q036          Race/Ethnicity
# 25  American Indian/Alaska Native     OWS       Q036          Race/Ethnicity
# 26                2 or more races     OWS       Q036          Race/Ethnicity
#
# ...

# %% [markdown]
# ##6.4) Dropping Missing values
# (According to the above observations)

# %%
columns_to_drop = ['race/ethnicity','income','age(years)','gender','education','total']
race.drop(columns=columns_to_drop, inplace=True)
columns_to_drop = ['income','race/ethnicity','age(years)','gender','education','total']
inc.drop(columns=columns_to_drop, inplace=True)
columns_to_drop = ['race/ethnicity','income','age(years)','gender','education','total']
age.drop(columns=columns_to_drop, inplace=True)
columns_to_drop = ['race/ethnicity','income','age(years)','gender','education','total']
edu.drop(columns=columns_to_drop, inplace=True)
columns_to_drop = ['race/ethnicity','income','age(years)','gender','education','total']
gen.drop(columns=columns_to_drop, inplace=True)
columns_to_drop = ['race/ethnicity','income','age(years)','gender','education','total']
total.drop(columns=columns_to_drop, inplace=True)

# %%
dataframes = [race,inc,age,edu,gen,total]

# %%
for i, df in enumerate(dataframes, start=1):
    null_count = df.isnull().sum().sum()
    print(f"Null values in df{i}: {null_count}")
# Out:
# Null values in df1: 0
# Null values in df2: 0
# Null values in df3: 0
# Null values in df4: 0
# Null values in df5: 0
# Null values in df6: 0

# %% [markdown]
# **Now we don't have any null values in our datasets.**

# %% [markdown]
# #7) Preprocessing

# %% [markdown]
# ## 7.1) Removing outliers for each dataframes

# %%
#creating function to remove outliers by using interquartile function
def remove_outliers(df):
    for col in df.select_dtypes(include=np.number).columns:
        q1 = df[col].quantile(0.25)
        q3 = df[col].quantile(0.75)
        iqr = q3 - q1
        lower_bound = q1 - (1.5 * iqr)
        upper_bound = q3 + (1.5 * iqr)
        df.drop(df[(df[col] < lower_bound) | (df[col] > upper_bound)].index, inplace=True)

# %%
for i in dataframes:
  remove_outliers(i)

# %% [markdown]
# ## 7.2) Size of each category after removing outliers

# %%
print(f'Shape of category Race/ethinicity is {race.shape}')
print(f'Shape of category Income range is {inc.shape}')
print(f'Shape of category Age range of sample is {age.shape}')
print(f'Shape of category Education is {edu.shape}')
print(f'Shape of category Gender is {gen.shape}')
print(f'Shape of category total is {total.shape}')
# Out:
# Shape of category Race/ethinicity is (8253, 10)
# Shape of category Income range is (12102, 10)
# Shape of category Age range of sample is (10701, 10)
# Shape of category Education is (7008, 10)
# Shape of category Gender is (3525, 10)
# Shape of category total is (1732, 10)

# %% [markdown]
# # 8) Feature Selection

# %% [markdown]
# ## 8.1) Dropping correlated feature

# %%
race.head(3)
# Out:
#     yearend locationabbr  sample_size classid questionid  \
# 21     2011           AL       1878.0     OWS       Q036
# 22     2011           AL        115.0     OWS       Q036
# 25     2011           AL         61.0     OWS       Q036
#
#    stratificationcategory1                stratification1  \
# 21          Race/Ethnicity             Non-Hispanic Black
# 22          Race/Ethnicity                       Hispanic
# 25          Race/Ethnicity  American Indian/Alaska Native
#
#    stratificationcategoryid1 stratificationid1  data_value
# 21                      RACE           RACEBLK        40.1
# 22                      RACE           RACEHIS        28.6
# 25                      RACE           RACENAA        32.9

# %%
columns_to_drop = ['stratificationcategory1','stratification1','stratificationcategoryid1']
race = race.drop(columns=columns_to_drop)
inc = inc.drop(columns=columns_to_drop)
age = age.drop(columns=columns_to_drop)
edu = edu.drop(columns=columns_to_drop)
gen = gen.drop(columns=columns_to_drop)
total = total.drop(columns=columns_to_drop)

# %%
race
# Out:
#        yearend locationabbr  sample_size classid questionid stratificationid1  \
# 21        2011           AL       1878.0     OWS       Q036           RACEBLK
# 22        2011           AL        115.0     OWS       Q036           RACEHIS
# 25        2011           AL         61.0     OWS       Q036           RACENAA
# 26        2011           AL         58.0     OWS       Q036         RACE2PLUS
# 49        2011           AL       1878.0     OWS       Q037           RACEBLK
# ...        ...          ...          ...     ...        ...               ...
# 53334     2016           GU        511.0      PA       Q047           RACEHPI
# 53336     2016           GU        203.0      PA       Q047         RACE2PLUS
# 53384     2016           VI        154.0      PA       Q047           RACEWHT
# 53385     2016           VI        820.0      PA       Q047           RACEBLK
# 53386     2016           VI        178.0      PA       Q047           RACEHIS
#
#        data_value
# ...

# %% [markdown]
# 1.stratificationcategory1, stratificationcategoryid1--> all the data is for income so we removed.
#
# 2.stratification1 ---> It is a income range and we already have stratificationid1 as abbrevation for this.

# %% [markdown]
# ## 8.2) Encoding

# %%
print(race.dtypes)
# Out:
# yearend                int64
# locationabbr          object
# sample_size          float64
# classid               object
# questionid            object
# stratificationid1     object
# data_value           float64
# dtype: object

# %% [markdown]
# ###8.2.1) Label Encoding (for ordinal categorical data):
#  Using label encoding when the categorical data have an inherent order or hierarchy.

# %%
from sklearn.preprocessing import LabelEncoder,StandardScaler

# %%
le = LabelEncoder()
race['locationabbr'] = le.fit_transform(race["locationabbr"])
race['classid'] = le.fit_transform(race["classid"])
race['questionid'] = le.fit_transform(race["questionid"])

inc['locationabbr'] = le.fit_transform(inc["locationabbr"])
inc['classid'] = le.fit_transform(inc["classid"])
inc['questionid'] = le.fit_transform(inc["questionid"])

age['locationabbr'] = le.fit_transform(age["locationabbr"])
age['classid'] = le.fit_transform(age["classid"])
age['questionid'] = le.fit_transform(age["questionid"])

gen['locationabbr'] = le.fit_transform(gen["locationabbr"])
gen['classid'] = le.fit_transform(gen["classid"])
gen['questionid'] = le.fit_transform(gen["questionid"])

edu['locationabbr'] = le.fit_transform(edu["locationabbr"])
edu['classid'] = le.fit_transform(edu["classid"])
edu['questionid'] = le.fit_transform(edu["questionid"])

total['locationabbr'] = le.fit_transform(total["locationabbr"])
total['classid'] = le.fit_transform(total["classid"])
total['questionid'] = le.fit_transform(total["questionid"])

# %%
dataframe = [race,inc,age,gen,edu,total]

# %%
race
# Out:
#        yearend  locationabbr  sample_size  classid  questionid  \
# 21        2011             1       1878.0        1           2
# 22        2011             1        115.0        1           2
# 25        2011             1         61.0        1           2
# 26        2011             1         58.0        1           2
# 49        2011             1       1878.0        1           3
# ...        ...           ...          ...      ...         ...
# 53334     2016            11        511.0        2           8
# 53336     2016            11        203.0        2           8
# 53384     2016            48        154.0        2           8
# 53385     2016            48        820.0        2           8
# 53386     2016            48        178.0        2           8
#
#       stratificationid1  data_value
# 21              RACEBLK        40.1
# 22              RACEHIS        28.6
# 25              RACENAA        32.9
# 26            RACE2PLUS        27.8
# ...

# %% [markdown]
# ### 8.2.2) One-Hot Encoding (for nominal categorical data):
# Using one-hot encoding when there is no specific order or hierarchy among the categories.

# %%
columns_to_drop = ['stratificationid1']
for i in range(len(dataframe)):
  dataframe[i] = dataframe[i].drop(columns=columns_to_drop)

# %%
# dataframe = [race,inc,age,gen,edu,total]

# %%
dataframe[0]
# Out:
#        yearend  locationabbr  sample_size  classid  questionid  data_value
# 21        2011             1       1878.0        1           2        40.1
# 22        2011             1        115.0        1           2        28.6
# 25        2011             1         61.0        1           2        32.9
# 26        2011             1         58.0        1           2        27.8
# 49        2011             1       1878.0        1           3        30.1
# ...        ...           ...          ...      ...         ...         ...
# 53334     2016            11        511.0        2           8        34.6
# 53336     2016            11        203.0        2           8        21.5
# 53384     2016            48        154.0        2           8        18.3
# 53385     2016            48        820.0        2           8        24.1
# 53386     2016            48        178.0        2           8        30.3
#
# [8253 rows x 6 columns]

# %% [markdown]
# ## 8.3) Saving files into csv
#
# Saving each category dataframes into csv file for further process.

# %%
dataframes = [race, inc, age, edu, gen, total]
categories = ['race', 'income', 'age', 'education', 'gender', 'total']

# %%
for i, df in enumerate(dataframes):
    filename = f'{categories[i]}.csv'
    df.to_csv(filename, index=False)

# %%
dataframe[0]
# Out:
#        yearend  locationabbr  sample_size  classid  questionid  data_value
# 21        2011             1       1878.0        1           2        40.1
# 22        2011             1        115.0        1           2        28.6
# 25        2011             1         61.0        1           2        32.9
# 26        2011             1         58.0        1           2        27.8
# 49        2011             1       1878.0        1           3        30.1
# ...        ...           ...          ...      ...         ...         ...
# 53334     2016            11        511.0        2           8        34.6
# 53336     2016            11        203.0        2           8        21.5
# 53384     2016            48        154.0        2           8        18.3
# 53385     2016            48        820.0        2           8        24.1
# 53386     2016            48        178.0        2           8        30.3
#
# [8253 rows x 6 columns]
